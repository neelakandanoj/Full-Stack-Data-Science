# %% [markdown]
# ## 5 number Summary and Box plot

# %%
# min,max,median,q1,q3,IQR

# %%
import numpy as np
lst_marks=[12.67,89,32,81,98,32,35,79,70,84,75,99,88,32]
min,q1,median,q3,max=np.quantile(lst_marks,[0.0,0.25,0.50,0.75,1.0])
min
# Out:
# np.float64(12.67)

# %%
min,q1,median,q3,max
# Out:
# (np.float64(12.67),
#  np.float64(32.75),
#  np.float64(77.0),
#  np.float64(87.0),
#  np.float64(99.0))

# %%
IQR=q3-q1
print(IQR)
# Out:
# 54.25

# %%
lower_fence=q1-1.5*(IQR)
higher_fence=q3+1.5*(IQR)

# %%
import seaborn as sns
sns.boxplot(lst_marks)
# Out:
# <Axes: >

# %%
lst_marks=[10,-20,-12.67,89,32,81,98,32,35,79,70,84,75,99,88,32,200,199]
sns.boxplot(lst_marks)
# Out:
# <Axes: >
